# %%
import os
import numpy as np
import pandas as pd

# %%
encuesta = pd.read_csv('Dataframe_unido.csv', index_col = 'index')
encuesta.head(2)
# Out:
#        time    age gender         Q3                 Q4  \
# index
# 0       910  50-54    Man      India  Bachelor’s degree
# 1       784  50-54    Man  Indonesia    Master’s degree
#
#                             Q5          Q6      Q8  \
# index
# 0                        Other  5-10 years  Python
# 1      Program/Project Manager   20+ years  Python
#
#                                                      Q11        Q13  ...  \
# index                                                                ...
# 0                                               A laptop  2-5 times  ...
# 1      A cloud computing platform (AWS, Azure, GCP, h...      Never  ...
#
#       Q39_Part_1 Q39_Part_2 Q39_Part_3 Q39_Part_4 Q39_Part_5 Q39_Part_6  \
# index
# 0            NaN        NaN        NaN    GitHub         NaN    Kaggle
# 1            NaN        NaN        NaN        NaN        NaN        NaN
#
#       Q39_Part_7 Q39_Part_8 Q39_Part_9 Q39_OTHER
# index
# ...

# %%
# Renombramos algunas columnas importantes con las que vamos a trabajar
encuesta.rename(columns = {'Q3': 'paises', 'Q4': 'titulo_academico', 'Q5': 'puesto_trabajo', 'Q6': 'años_experiencia','Q7': 'lenguaje_programacion', 'Q9': 'entorno_desarrollo',
                           'Q11': 'plataforma_informatica', 'Q14': 'libreria_visualizacion', 'Q20': 'sector_laboral', 'Q21': 'tamaño_empresa', 'Q24': 'funciones_puesto', 
                           'Q25': 'salario', 'Q33': 'servidor_datos', 'Q34': 'herramienta_BI', 'Q41': 'herramienta_analisis'}, inplace = True)

# %%
encuesta.head()
# Out:
#        time    age gender     paises   titulo_academico  \
# index
# 0       910  50-54    Man      India  Bachelor’s degree
# 1       784  50-54    Man  Indonesia    Master’s degree
# 2       924  22-24    Man   Pakistan    Master’s degree
# 3       575  45-49    Man     Mexico    Doctoral degree
# 4       781  45-49    Man      India    Doctoral degree
#
#                 puesto_trabajo años_experiencia      Q8  \
# index
# 0                        Other       5-10 years  Python
# 1      Program/Project Manager        20+ years  Python
# 2            Software Engineer        1-3 years  Python
# 3           Research Scientist        20+ years  Python
# 4                        Other        < 1 years  Python
#
#                                   plataforma_informatica                 Q13  \
# index
# 0                                               A laptop           2-5 times
# 1      A cloud computing platform (AWS, Azure, GCP, h...               Never
# ...

# %%
# Eliminamos la columna time porque no nos interesa
encuesta = pd.DataFrame(encuesta.drop(['time', 'Q8', 'Q13', 'Q15', 'Q22', 'Q23', 'Q35', 'Q12', 'Q16', 'Q10_Part_1', 'Q10_Part_2', 'Q10_Part_16', 'Q17', 'Q32', 'Q28', 
                                       'Q39_Part_1', 'Q39_Part_2', 'Q39_Part_3', 'Q39_Part_5', 'Q39_Part_8','Q39_OTHER'], axis = 1))
encuesta.head()
# Out:
#          age gender     paises   titulo_academico           puesto_trabajo  \
# index
# 0      50-54    Man      India  Bachelor’s degree                    Other
# 1      50-54    Man  Indonesia    Master’s degree  Program/Project Manager
# 2      22-24    Man   Pakistan    Master’s degree        Software Engineer
# 3      45-49    Man     Mexico    Doctoral degree       Research Scientist
# 4      45-49    Man      India    Doctoral degree                    Other
#
#       años_experiencia                             plataforma_informatica  \
# index
# 0           5-10 years                                           A laptop
# 1            20+ years  A cloud computing platform (AWS, Azure, GCP, h...
# 2            1-3 years                                           A laptop
# 3            20+ years  A cloud computing platform (AWS, Azure, GCP, h...
# 4            < 1 years  A cloud computing platform (AWS, Azure, GCP, h...
#
# ...

# %% [markdown]
# EXPLORACIÓN PRIMERA

# %%
encuesta['puesto_trabajo'].value_counts()
# Out:
# Student                         6804
# Data Scientist                  3616
# Software Engineer               2449
# Other                           2393
# Data Analyst                    2301
# Currently not employed          1986
# Research Scientist              1538
# Machine Learning Engineer       1499
# Business Analyst                 968
# Program/Project Manager          849
# Data Engineer                    668
# Product Manager                  319
# Statistician                     313
# DBA/Database Engineer            171
# Developer Relations/Advocacy      99
# Name: puesto_trabajo, dtype: int64

# %%
# Para que nos muestre todas las columnas del datadrame
pd.options.display.max_columns = None

# %%
# Filtramos por los dos puestos que nos interesan
df_data = encuesta[(encuesta['puesto_trabajo'] == 'Data Analyst') | (encuesta['puesto_trabajo'] == 'Business Analyst')]
df_data.head(2)
# Out:
#          age     gender                    paises  \
# index
# 16     50-54        Man                   Belgium
# 32     22-24  Nonbinary  United States of America
#
#                                         titulo_academico puesto_trabajo  \
# index
# 16                                     Bachelor’s degree   Data Analyst
# 32     Some college/university study without earning ...   Data Analyst
#
#       años_experiencia         plataforma_informatica  \
# index
# 16           20+ years                       A laptop
# 32           < 1 years  A personal computer / desktop
#
#                   sector_laboral        tamaño_empresa      salario  \
# index
# 16                 Energy/Mining  1000-9,999 employees  2,000-2,999
# 32     Manufacturing/Fabrication     250-999 employees          NaN
#
#              Q26 servidor_datos  \
# index
# 16     $0 ($USD)            NaN
# 32           NaN            NaN
#
#                                     herramienta_analisis  \
# index
# ...

# %%
# Sacamos los uniques de columnas que creemos importantes
df_data['age'].unique()
# Out:
# array(['50-54', '22-24', '30-34', '40-44', '70+', '45-49', '18-21',
#        '55-59', '25-29', '35-39', '60-69'], dtype=object)

# %%
df_data['paises'].unique()
# Out:
# array(['Belgium', 'United States of America', 'Egypt', 'China',
#        'South Africa', 'Other', 'India', 'Israel', 'Colombia', 'Austria',
#        'Brazil', 'Japan', 'Russia', 'Ukraine', 'Pakistan', 'Canada',
#        'Nigeria', 'Mexico', 'Tunisia', 'Italy', 'Poland', 'Spain',
#        'Indonesia', 'Sri Lanka',
#        'United Kingdom of Great Britain and Northern Ireland', 'Turkey',
#        'Kenya', 'Iran, Islamic Republic of...', 'South Korea', 'Peru',
#        'Viet Nam', 'United Arab Emirates', 'Germany', 'France', 'Greece',
#        'Taiwan', 'Portugal', 'Australia', 'Philippines', 'Saudi Arabia',
#        'Singapore', 'Chile', 'Netherlands', 'Argentina', 'Ghana',
#        'Morocco', 'Thailand', 'Switzerland', 'Hong Kong (S.A.R.)',
#        'Ecuador', 'Bangladesh', 'Malaysia', 'Romania', 'Norway',
#        'Ethiopia', 'Czech Republic',
#        'I do not wish to disclose my location', 'Ireland', 'Sweden',
# ...

# %%
df_data['salario'].unique()
# Out:
# array(['2,000-2,999', nan, '7,500-9,999', '$0-999', '25,000-29,999',
#        '60,000-69,999', '20,000-24,999', '1,000-1,999', '100,000-124,999',
#        '125,000-149,999', '5,000-7,499', '70,000-79,999', '10,000-14,999',
#        '30,000-39,999', '15,000-19,999', '3,000-3,999', '4,000-4,999',
#        '40,000-49,999', '200,000-249,999', '80,000-89,999',
#        '50,000-59,999', '150,000-199,999', '90,000-99,999',
#        '250,000-299,999', '>$1,000,000', '300,000-499,999',
#        '$500,000-999,999'], dtype=object)

# %%
df_data.describe()
# Out:
#           age gender paises titulo_academico puesto_trabajo años_experiencia  \
# count    3269   3269   3269             3269           3269             3269
# unique     11      5     66                7              2                7
# top     25-29    Man  India  Master’s degree   Data Analyst        1-3 years
# freq      788   2538    795             1514           2301              991
#
#        plataforma_informatica        sector_laboral  tamaño_empresa salario  \
# count                    2980                  3111            3092    2924
# unique                      6                    18               5      26
# top                  A laptop  Computers/Technology  0-49 employees  $0-999
# freq                     2082                   550             908     679
#
#               Q26 servidor_datos  \
# count        2887            807
# unique          6             20
# top     $0 ($USD)         MySQL
# freq         1235            206
#
# ...

# %%
df_data.describe().T
# Out:
#                        count unique  \
# age                     3269     11
# gender                  3269      5
# paises                  3269     66
# titulo_academico        3269      7
# puesto_trabajo          3269      2
# años_experiencia        3269      7
# plataforma_informatica  2980      6
# sector_laboral          3111     18
# tamaño_empresa          3092      5
# salario                 2924     26
# Q26                     2887      6
# servidor_datos           807     20
# herramienta_analisis    2509      6
# lenguaje_programacion   2994    250
# entorno_desarrollo      2991    474
# libreria_visualizacion  2924    208
# funciones_puesto        2971     73
# herramienta_BI          1701    155
# Q39_Part_4               745      1
# Q39_Part_6               573      1
# Q39_Part_7               275      1
# Q39_Part_9               610      1
#
#                                                                       top  \
# ...

# %%
#Filtramos las personas que trabajan en Data Analyst para saber las herramientas que utilizan cada una de ellas
df_data.notnull().sum()
# Out:
# age                       3269
# gender                    3269
# paises                    3269
# titulo_academico          3269
# puesto_trabajo            3269
# años_experiencia          3269
# plataforma_informatica    2980
# sector_laboral            3111
# tamaño_empresa            3092
# salario                   2924
# Q26                       2887
# servidor_datos             807
# herramienta_analisis      2509
# lenguaje_programacion     2994
# entorno_desarrollo        2991
# libreria_visualizacion    2924
# funciones_puesto          2971
# herramienta_BI            1701
# Q39_Part_4                 745
# Q39_Part_6                 573
# Q39_Part_7                 275
# Q39_Part_9                 610
# dtype: int64

# %%
# Herramienta más usadas por Business Analyst y Data Analyst
df_herramienta = df_data['lenguaje_programacion'].value_counts().reset_index()
df_herramienta.head()
# Out:
#             index  lenguaje_programacion
# 0     Python, SQL                    622
# 1          Python                    481
# 2  Python, R, SQL                    319
# 3       Python, R                    140
# 4             SQL                    114

# %%
# Número de hombres y mujeres en el registro Business Analyst y Data Analyst
df_genero = df_data['gender'].value_counts().reset_index()
df_genero.head(2)
# Out:
#    index  gender
# 0    Man    2538
# 1  Woman     680

# %%
df_data['Q26'].value_counts().reset_index()
# Out:
#                      index   Q26
# 0                $0 ($USD)  1235
# 1                $100-$999   526
# 2             $1000-$9,999   406
# 3                   $1-$99   380
# 4          $10,000-$99,999   204
# 5  $100,000 or more ($USD)   136

# %% [markdown]
# -----

# %% [markdown]
# POSIBLES PREGUNTAS:
# - Relación entre el género(mujeres) con el tamaño de empresa.
# - Herramientas más utilizadas segun el puesto: business o data.
# - Título académico y salario.
# - Paises: hacder un top10.

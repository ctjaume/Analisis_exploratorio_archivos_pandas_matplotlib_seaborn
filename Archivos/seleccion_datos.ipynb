# %%
import os
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('../datos/Dataframe_unido.csv', index_col = 'index')
df.head(2)
# Out:
#        time    age gender         Q3                 Q4  \
# index
# 0       910  50-54    Man      India  Bachelor’s degree
# 1       784  50-54    Man  Indonesia    Master’s degree
#
#                             Q5          Q6      Q8  \
# index
# 0                        Other  5-10 years  Python
# 1      Program/Project Manager   20+ years  Python
#
#                                                      Q11        Q13  ...  \
# index                                                                ...
# 0                                               A laptop  2-5 times  ...
# 1      A cloud computing platform (AWS, Azure, GCP, h...      Never  ...
#
#       Q39_Part_1 Q39_Part_2 Q39_Part_3 Q39_Part_4 Q39_Part_5 Q39_Part_6  \
# index
# 0            NaN        NaN        NaN    GitHub         NaN    Kaggle
# 1            NaN        NaN        NaN        NaN        NaN        NaN
#
#       Q39_Part_7 Q39_Part_8 Q39_Part_9 Q39_OTHER
# index
# ...

# %%
# Renombramos algunas columnas importantes con las que vamos a trabajar
df.rename(columns = {'Q3': 'paises', 'Q4': 'titulo_academico', 'Q5': 'puesto_trabajo', 'Q6': 'años_experiencia','Q7': 'lenguaje_programacion', 'Q9': 'entorno_desarrollo',
                           'Q11': 'plataforma_informatica', 'Q14': 'libreria_visualizacion', 'Q20': 'sector_laboral', 'Q21': 'tamaño_empresa', 'Q24': 'funciones_puesto', 
                           'Q25': 'salario', 'Q33': 'servidor_datos', 'Q34': 'herramienta_BI', 'Q41': 'herramienta_analisis'}, inplace = True)

# %%
df.head()
# Out:
#        time    age gender     paises   titulo_academico  \
# index
# 0       910  50-54    Man      India  Bachelor’s degree
# 1       784  50-54    Man  Indonesia    Master’s degree
# 2       924  22-24    Man   Pakistan    Master’s degree
# 3       575  45-49    Man     Mexico    Doctoral degree
# 4       781  45-49    Man      India    Doctoral degree
#
#                 puesto_trabajo años_experiencia      Q8  \
# index
# 0                        Other       5-10 years  Python
# 1      Program/Project Manager        20+ years  Python
# 2            Software Engineer        1-3 years  Python
# 3           Research Scientist        20+ years  Python
# 4                        Other        < 1 years  Python
#
#                                   plataforma_informatica                 Q13  \
# index
# 0                                               A laptop           2-5 times
# 1      A cloud computing platform (AWS, Azure, GCP, h...               Never
# ...

# %%
# Eliminamos la columna time porque no nos interesa
df = pd.DataFrame(df.drop(['time', 'Q8', 'Q13', 'Q15', 'Q22', 'Q23', 'Q35', 'Q12', 'Q16', 'Q10_Part_1', 'Q10_Part_2', 'Q10_Part_16', 'Q17', 'Q32', 'Q28', 
                                       'Q39_Part_1', 'Q39_Part_2', 'Q39_Part_3', 'Q39_Part_5', 'Q39_Part_8','Q39_OTHER'], axis = 1))
df.head()
# Out:
#          age gender     paises   titulo_academico           puesto_trabajo  \
# index
# 0      50-54    Man      India  Bachelor’s degree                    Other
# 1      50-54    Man  Indonesia    Master’s degree  Program/Project Manager
# 2      22-24    Man   Pakistan    Master’s degree        Software Engineer
# 3      45-49    Man     Mexico    Doctoral degree       Research Scientist
# 4      45-49    Man      India    Doctoral degree                    Other
#
#       años_experiencia                             plataforma_informatica  \
# index
# 0           5-10 years                                           A laptop
# 1            20+ years  A cloud computing platform (AWS, Azure, GCP, h...
# 2            1-3 years                                           A laptop
# 3            20+ years  A cloud computing platform (AWS, Azure, GCP, h...
# 4            < 1 years  A cloud computing platform (AWS, Azure, GCP, h...
#
# ...

# %%
# Guardamos el dataframe modificado
df.to_csv('../datos/df_renombrado.csv')

# %%
"""
def unir_col(*args):
    lista = []
    for x in args:
        if str(x) != "nan":
            lista.append(str(x))
        else:
            pass

    return lista
    
"""

# %%
"""
final["prueba"] = final.apply(lambda dataframe: unir_col(dataframe["Q7"], dataframe["Python2"], dataframe["col2"]), axis = 1)

"""

# %%
import os
import numpy as np
import pandas as pd

# %%
encuesta = pd.read_csv('Dataframe_unido.csv', index_col = 'index')
encuesta.head(2)
# Out:
#        time    age gender         Q3                 Q4  \
# index
# 0       910  50-54    Man      India  Bachelor’s degree
# 1       784  50-54    Man  Indonesia    Master’s degree
#
#                             Q5          Q6      Q8  \
# index
# 0                        Other  5-10 years  Python
# 1      Program/Project Manager   20+ years  Python
#
#                                                      Q11        Q13  ...  \
# index                                                                ...
# 0                                               A laptop  2-5 times  ...
# 1      A cloud computing platform (AWS, Azure, GCP, h...      Never  ...
#
#       Q39_Part_1 Q39_Part_2 Q39_Part_3 Q39_Part_4 Q39_Part_5 Q39_Part_6  \
# index
# 0            NaN        NaN        NaN    GitHub         NaN    Kaggle
# 1            NaN        NaN        NaN        NaN        NaN        NaN
#
#       Q39_Part_7 Q39_Part_8 Q39_Part_9 Q39_OTHER
# index
# ...

# %%
# Renombramos algunas columnas importantes con las que vamos a trabajar
encuesta.rename(columns = {'Q3': 'paises', 'Q4': 'título_académico', 'Q5': 'puesto_trabajo', 'Q6': 'años_experiencia', 'Q8': 'lenguaje_programación', 'Q11': 'herramientas_empresas', 'Q25': 'salario'}, inplace = True)

# %%
encuesta.head()
# Out:
#        time    age gender     paises   título_académico  \
# index
# 0       910  50-54    Man      India  Bachelor’s degree
# 1       784  50-54    Man  Indonesia    Master’s degree
# 2       924  22-24    Man   Pakistan    Master’s degree
# 3       575  45-49    Man     Mexico    Doctoral degree
# 4       781  45-49    Man      India    Doctoral degree
#
#                 puesto_trabajo años_experiencia lenguaje_programación  \
# index
# 0                        Other       5-10 years                Python
# 1      Program/Project Manager        20+ years                Python
# 2            Software Engineer        1-3 years                Python
# 3           Research Scientist        20+ years                Python
# 4                        Other        < 1 years                Python
#
#                                    herramientas_empresas                 Q13  \
# index
# 0                                               A laptop           2-5 times
# ...

# %%
# Eliminamos la columna time porque no nos interesa
encuesta = pd.DataFrame(encuesta.drop('time', axis = 1))
encuesta.head()
# Out:
#          age gender     paises   título_académico           puesto_trabajo  \
# index
# 0      50-54    Man      India  Bachelor’s degree                    Other
# 1      50-54    Man  Indonesia    Master’s degree  Program/Project Manager
# 2      22-24    Man   Pakistan    Master’s degree        Software Engineer
# 3      45-49    Man     Mexico    Doctoral degree       Research Scientist
# 4      45-49    Man      India    Doctoral degree                    Other
#
#       años_experiencia lenguaje_programación  \
# index
# 0           5-10 years                Python
# 1            20+ years                Python
# 2            1-3 years                Python
# 3            20+ years                Python
# 4            < 1 years                Python
#
#                                    herramientas_empresas                 Q13  \
# index
# 0                                               A laptop           2-5 times
# ...

# %% [markdown]
# EXPLORACIÓN PRIMERA

# %%
encuesta['puesto_trabajo'].value_counts()
# Out:
# Student                         6804
# Data Scientist                  3616
# Software Engineer               2449
# Other                           2393
# Data Analyst                    2301
# Currently not employed          1986
# Research Scientist              1538
# Machine Learning Engineer       1499
# Business Analyst                 968
# Program/Project Manager          849
# Data Engineer                    668
# Product Manager                  319
# Statistician                     313
# DBA/Database Engineer            171
# Developer Relations/Advocacy      99
# Name: puesto_trabajo, dtype: int64

# %%
# Filtramos por los dos puestos que nos interesan
encuesta_puesto = encuesta[(encuesta['puesto_trabajo'] == 'Business Analyst') | (encuesta['puesto_trabajo'] == 'Data Analyst')]
encuesta_puesto.head()
# Out:
#          age     gender                    paises  \
# index
# 16     50-54        Man                   Belgium
# 32     22-24  Nonbinary  United States of America
# 33     30-34      Woman                     Egypt
# 46     22-24        Man                     China
# 52     40-44        Man              South Africa
#
#                                         título_académico puesto_trabajo  \
# index
# 16                                     Bachelor’s degree   Data Analyst
# 32     Some college/university study without earning ...   Data Analyst
# 33                                     Bachelor’s degree   Data Analyst
# 46     Some college/university study without earning ...   Data Analyst
# 52                                       Master’s degree   Data Analyst
#
#       años_experiencia lenguaje_programación          herramientas_empresas  \
# index
# 16           20+ years                Python                       A laptop
# ...

# %%
encuesta_puesto['puesto_trabajo'].value_counts()
# Out:
# Data Analyst        2301
# Business Analyst     968
# Name: puesto_trabajo, dtype: int64

# %%
# NOS HEMOS QUEDADO AQUÍ PORQUE QUEREMOS FILTRAR TODO DE LOS DOS PUESTOS
def filtro(dataframe):
    if encuesta_puesto['puesto_trabajo'] == 'Data Analyst':
        return encuesta_puesto[1]

# %%
filtro(encuesta_puesto)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /var/folders/fr/wg652zl15fv6svll64p1m7380000gn/T/ipykernel_4807/3641873853.py in <module>
# ----> 1 filtro(encuesta_puesto)
#
# TypeError: filtro() takes 0 positional arguments but 1 was given
